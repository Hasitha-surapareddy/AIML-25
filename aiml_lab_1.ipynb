# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasitha-surapareddy/AIML-25/blob/main/aiml_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
array1
# Out:
# array([1, 2, 3])

# %%
type(list1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1 is:",array1*array2)
print("array2 divided by array1 is:",array1/array2)
print("array2 raised to power of array1 is:",array1**array2)
print(f"{array2} raised to power of {array1} is:,{array2*array1}")
# Out:
# array2 multiplied by array1 is: [3 4 3]
# array2 divided by array1 is: [0.33333333 1.         3.        ]
# array2 raised to power of array1 is: [1 4 3]
# [3 2 1] raised to power of [1 2 3] is:,[3 4 3]

# %%
print("sine:",np.sin(array1))
print("natural logarithm",np.log(array1))
print("base-10 logarithm",np.log10(array1))
print("base-2 logarithm",np.log2(array1))
print("Exponential:",np.exp(array1))
# Out:
# sine: [0.84147098 0.90929743 0.14112001]
# natural logarithm [0.         0.69314718 1.09861229]
# base-10 logarithm [0.         0.30103    0.47712125]
# base-2 logarithm [0.        1.        1.5849625]
# Exponential: [ 2.71828183  7.3890561  20.08553692]

# %%
print("adding 2 numpy arrays{array1} and {array2} together:",array1+array2)
# Out:
# adding 2 numpy arrays{array1} and {array2} together: [4 4 4]

# %%
print(f"adding 2 numpy arrays {array1} and {array2} together:{array1+array2}")
# Out:
# adding 2 numpy arrays [1 2 3] and [3 2 1] together:[4 4 4]

# %%
people=['greesy','brandon','emily','nic','landon','lily','jeremy','eli','daisy','milo']
age=[21,22,19,13,11,20,14,17,19,34]
weight=[55,50,45,47,58,60,49,67,55,60]
height=[146,187,197,145,197,153,113,164,173,132]
import matplotlib.pyplot  as plt
plt.scatter(weight,height)
plt.title("relationship between weight and height of patients")
plt.ylabel("height in metres")
plt.xlabel("weight in kgs")
plt.show()

# %%
people=['sharini','greeshma','hasitha','sreeja','Harini']
weight=[55,56,60,47,40]
height=[146,187,197,145,148]
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')
plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("people")
plt.ylabel("weight in kgs")
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))
plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bins=5)
plt.title("histogram of patient weight")
plt.xlabel("weight in kgs")
plt.show()
